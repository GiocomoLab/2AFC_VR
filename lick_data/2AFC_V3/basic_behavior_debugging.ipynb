# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy as sp
from behavior_analysis import process_data as pd
import behavior_analysis as bd
from glob import glob

# %matplotlib inline

#mice = ['4058541.2'] #, '4058541.2', '4058541.3', '4058541.4']

# %%
baseDir = '/Volumes/mplitt/VR/2AFC_V3/'
def plot_single_mouse(mouse):
    
    c = pd(mouse,[],basedir='home')
    OneSidedSessions = glob(baseDir+mouse+"/OneSidedCues_noservo_*Licks*.txt")
    HalfOneSidedSessions = 
    FullTrain = 
    
    print(mouse)
    c = pd(mouse,['HalfOneSidedCue_quinine_0_' ],basedir="work")
    c.save_sessions()
    
    R,D = c.load_sessions()
    
    for sess in c.sessions:
        print(sess)
        try:
            bd.reward_trig_lick_rate(R[sess],title=mouse+'_'+sess)
            mv, pRight,RT, omit = bd.psychometrics(R[sess],title=mouse+'_'+sess,plots='all')
        except:
            print("plot fail")
# Out:
# 4058541.2
# C:\cygwin64\home\mplitt\2AFC_VR\lick_data\2AFC_V3\behavior_analysis.py:505: RuntimeWarning: divide by zero encountered in true_divide
#   rawSpeed = np.divide(np.ediff1d(pos,to_end=0),np.ediff1d(t,to_end=1))
# C:\cygwin64\home\mplitt\2AFC_VR\lick_data\2AFC_V3\behavior_analysis.py:505: RuntimeWarning: invalid value encountered in true_divide
#   rawSpeed = np.divide(np.ediff1d(pos,to_end=0),np.ediff1d(t,to_end=1))
# C:\cygwin64\home\mplitt\2AFC_VR\lick_data\2AFC_V3\behavior_analysis.py:506: RuntimeWarning: invalid value encountered in greater
#   notTeleports = np.where(rawSpeed>-50)[0]
# C:\Users\mplitt\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# C:\Users\mplitt\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
# Out:
# ['', 'OneSidedCues_0_1__Licks.txt']
